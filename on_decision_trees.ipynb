# %% [markdown]
# # On Decision Trees

# %%
# You may need to run the following bash commands in order to
# make sure you have the relevant packages installed.

# !brew install graphviz
# !conda install -c pyetras pydot2

# %%
import pandas as pd
from math import log
from sklearn.tree import DecisionTreeClassifier
import numpy as np
from sklearn.tree import export_graphviz
import pydotplus
from sklearn.externals.six import StringIO
from IPython.display import Image

# %% [markdown]
# Let's do a simple internet image search for decision trees.
#
# What does this have to do with a data science predictive model?

# %% [markdown]
# - splitting / partitioning my data (filter)
# - the resulting splits can help make predictions more accurate

# %% [markdown]
# A decision tree is a machine learning model that works by *partitioning* our sample space in a hierarchical way.
#
# *How* do we partition the space? The key idea is that some attributes provide more *information* than others when trying to make a decision.
#
# ## Motivating Example
#
# Suppose a friend said to you: "Hey, you have experience predicting housing prices! I'm hoping you can predict what my house will sell for."
#
# What are the top questions you would ask about your friend's house? Let's make a list:

# %% [markdown]
# - lot size
# - sqaure foot
# - year built
# - bed/bath count
# - location
# - waterfront?
# - school district

# %% [markdown]
# Now: *Why* are these questions good questions?

# %% [markdown]
# changes in price are correlated with variations in these factors

# %% [markdown]
# ## A Bit More Detail
#
# Suppose that we work for a retail company and that we're working on a classification model that can predict whether customers will pay their bills or not. In effect what we want to do is to ask questions that will *sort* our customers into two classes: (i) those who pay and (ii) those who don't.
#
# (Can you think of any ethical issues that could arise here?)
#
# **If I ask enough data-dividing questions, I can produce a partition of my data such that, in each subset, either (i) everyone is a payer or (ii) everyone is a non-payer.**
#
# Each row in my dataframe represents a customer, and I have many predictors (columns) in my dataframe, including:
#
# - salary
# - total_bill
# - club_member (boolean)
# - age
#
# Let's look at a simple set of data. **The 'paid' column is our target or dependent variable.**

# %%
custs = pd.DataFrame([[45000, 1000, True, 20, False],
                      [70000, 100, True, 50, True],
             [30000, 2000, False, 25, False],
                      [90000, 500, True, 44, True],
             [70000, 200, True, 48, False]],
            columns=['salary', 'total_bill', 'club_member',
                     'age', 'paid'])
custs
# Out:
#    salary  total_bill  club_member  age   paid
# 0   45000        1000         True   20  False
# 1   70000         100         True   50   True
# 2   30000        2000        False   25  False
# 3   90000         500         True   44   True
# 4   70000         200         True   48  False

# %% [markdown]
# ## Partitioning
#
# I partition my data by asking a question about the independent variables. The goal is to ask the right questions in the right order so that the resultant groups are "pure" with respect to the dependent variable. More on this below!
#
# Suppose, for example, that I choose:
#
# ### Is the customer a club member?
#
# This would divide my data into two groups:
#
# - Group 1 (club_member = True):
#
# data points: 0, 1, 3, 4
#
# - Group 2 (club_member = False):
#
# data points: 2
#
# #### Key Question: How are the values of the target distributed in this group?
# In Group 1, I have, in order: non-payer, payer, payer, non-payer.
#
# In Group 2, I have a single non-payer.
#
# While I've isolated one of the customers who haven't paid in the second group, the first group is an even mix of payers and non-payers. So this split is not particularly good.
#
# Would a different question split our data more effectively? Let's try:
#
# ### "Is the customer's salary less than $60k?"
#
# This would divide my data into two groups:
#
# - Group 1 (salary < 60000):
#
# data points: 0, 2
#
# -  Group 2 (salary $\geq$ 60000):
#
# data points: 1, 3, 4
#
# #### Key Question: How are the values of the target distributed in this group?
# In Group 1, I have two non-payers.
#
# In Group 2, I have, in order: payer, payer, non-payer.
#
# This does a better job of partitioning my data according to the values of the dependent variable: The first group contains only customers who have not paid their bills, and the second group contains only one customer who has not paid her bill.
#
# So a (very simple!) model that predicts:
# (i) that customers who make less than \$60k *won't* pay their bill, and
# (ii) that customers who make \$60k or more *will* pay their bill
#
# would perform fairly well.
#
# But how would my partition be *best* split? And how do I really know that the second split is better than the first? Can I do better than intuition here?
#
# ## Entropy and Information Gain
#
# The goal is to have our ultimate classes be fully "ordered" (for a binary dependent variable, we'd have the 1's in one group and the 0's in the other). So one way to assess the value of a split is to measure how *disordered* our groups are, and there is a notion of *entropy* that measures precisely this.
#
# The entropy of the whole dataset is given by:
#
# $\large E = -\Sigma^n_i p_i\log_2(p_i)$,
#
# where $p_i$ is the probability of belonging to the $i$th group, where $n$ is the number of groups (i.e. target values).
#
# **Entropy will always be between 0 and 1. The closer to 1, the more disordered your group.**
#
# To repeat, in the present case we have only two groups of interest: the payers and the non-payers.
#
# Two out of five are payers and three out of five are non-payers, so **these are the relevant probabilities** for our calculation of entropy.
#
# So our entropy for this toy dataset is:
#
# $-0.4*\log_2(0.4) -0.6*\log_2(0.6)$.
#
# Let's use the ```math``` library's `log()` function to calculate this:

# %%
# Your code here!
# we want the BINARY log
# this is the 'parent' entropy, entropy we are trying to improve by splitting
ent_whole = -0.4 * log(0.4, 2) - 0.6 * log(0.6, 2)
ent_whole
# Out:
# 0.9709505944546686

# %% [markdown]
# That's pretty disordered!

# %% [markdown]
# To calculate the entropy of a *split*, we're going to want to calculate the entropy of each of the groups made by the split, and then calculate a weighted average of those groups' entropies––weighted, that is, by the size of the groups. Let's calculate the entropy of the split produced by our question above about salary:
#
# Group 1:
#
# $E_{g1} = - 1 * \log_2(1) = 0$. This is a pure group! The probability of being a payer in Group 1 is 0 and the probability of being a non-payer in Group 1 is 1.
#
# Group 2:
#
# $E_{g2} = -\frac{2}{3} * \log_2\left(\frac{2}{3}\right) - \frac{1}{3} * \log_2\left(\frac{1}{3}\right)$.
#
# Once again, using ```math```:

# %%
# Your code here!

ent_grp1 = -1 * log(1,2)
ent_grp1

ent_grp2 = -2/3 * log(2/3,2) - 1/3 * log(1/3, 2)
ent_grp2
# Out:
# 0.9182958340544896

# %% [markdown]
# To get the whole entropy for this split, we'll do a weighted sum of the two group entropies:

# %%
# Your code here!
# this is the entropy for the split
0.4 * ent_grp1 + 0.6 * ent_grp2
# Out:
# 0.5509775004326937

# %% [markdown]
# For a given split, the **information gain** is simply the entropy of the parent group less the entropy of the split.
#
# For a given parent, then, we maximize our model's performance by *minimizing* the split's entropy.
#
# What we'd like to do then is:
#
# 1. to look at the entropies of all possible splits, and
# 2. to choose the split with the lowest entropy.
#
# In practice there are far too many splits for it to be practical for a person to calculate all these different entropies ...
#
# ... but we can make computers do these calculations for us!

# %% [markdown]
# ## Gini Impurity
#
# An alternative metric to entropy comes from the work of Corrado Gini. The Gini Impurity is defined as:
#
# $\large G = 1 - \Sigma_ip_i^2$, or, equivalently, $\large G = \Sigma_ip_i(1-p_i)$.
#
# where, again, $p_i$ is the probability of belonging to the $i$th group.
#
# **Gini Impurity will always be between 0 and 0.5. The closer to 0.5, the more disordered your group.**

# %% [markdown]
# Exercise: Calculate the Gini Impurity for our toy dataset above.

# %%
# Your code here!
1 - (0.6**2 + 0.4**2)
# Out:
# 0.48

# %% [markdown]
# ## Coding Trees in Python
#
# Scikit-learn has a tree module, which houses both a DecisionTreeClassifier and a DecisionTreeRegressor. As is probably clear by now, the former is for classification problems (discrete target) and the latter is for regression problems (continuous target). Let's use the classifier.
#
# (How does the regressor work? Information gain and Gini impurity make sense only for discrete classes. What we need for a continuous target is some measure of the *spread* of those values, and so the natural move here is to split our groups in ways that will most *reduce the standard deviation of those groups*. For more on this, see [here](https://www.saedsayad.com/decision_tree_reg.htm).)

# %%
ct = DecisionTreeClassifier(criterion='entropy', random_state=1)    # Check out all the
                                                                    # hyperparameter options here!

ct.fit(custs.drop('paid', axis=1), custs['paid'])
ct.score(custs.drop('paid', axis=1), custs['paid'])         # score is the accuracy (from a confusion matrix)
                                                            # of predictions
# Out:
# 1.0

# %% [markdown]
# Let's visualize this!

# %%
def describe_tree(ct):
    n_nodes = ct.tree_.node_count
    children_left = ct.tree_.children_left
    children_right = ct.tree_.children_right
    feature = ct.tree_.feature
    threshold = ct.tree_.threshold

    # This code courtesy of sklearn:
    # https://scikit-learn.org/stable/auto_examples/tree/plot_unveil_tree_structure.html


    # The tree structure can be traversed to compute various properties such
    # as the depth of each node and whether or not it is a leaf.
    node_depth = np.zeros(shape=n_nodes, dtype=np.int64)
    is_leaves = np.zeros(shape=n_nodes, dtype=bool)
    stack = [(0, -1)]  # seed is the root node id and its parent depth
    while len(stack) > 0:
        node_id, parent_depth = stack.pop()
        node_depth[node_id] = parent_depth + 1

        # If we have a test node
        if (children_left[node_id] != children_right[node_id]):
            stack.append((children_left[node_id], parent_depth + 1))
            stack.append((children_right[node_id], parent_depth + 1))
        else:
            is_leaves[node_id] = True

    print("The binary tree structure has %s nodes and has "
          "the following tree structure:"
          % n_nodes)
    for i in range(n_nodes):
        if is_leaves[i]:
            print("%snode=%s leaf node." % (node_depth[i] * "\t", i))
        else:
            print("%snode=%s test node: go to node %s if X[:, %s] <= %s else to "
                  "node %s."
                  % (node_depth[i] * "\t",
                     i,
                     children_left[i],
                     feature[i],
                     threshold[i],
                     children_right[i],
                     ))
    print()
describe_tree(ct)
# Out:
# The binary tree structure has 7 nodes and has the following tree structure:
# node=0 test node: go to node 1 if X[:, 3] <= 34.5 else to node 2.
# 	node=1 leaf node.
# 	node=2 test node: go to node 3 if X[:, 0] <= 80000.0 else to node 6.
# 		node=3 test node: go to node 4 if X[:, 3] <= 49.0 else to node 5.
# 			node=4 leaf node.
# 			node=5 leaf node.
# 		node=6 leaf node.

# %%
# How many nodes do we have?

ct.tree_.node_count
# Out:
# 7

# %%
# This tells us which node is immediately to the left of each node in our tree.
# -1s represent leaf nodes
ct.tree_.children_left
# Out:
# array([ 1, -1,  3,  4, -1, -1, -1])

# %%
# This tells us which node is immediately to the right of each node in our tree.
# -1s represent leaf nodes
ct.tree_.children_right
# Out:
# array([ 2, -1,  6,  5, -1, -1, -1])

# %% [markdown]
# ## Another Visualization

# %%
dot_file = StringIO()

export_graphviz(ct, out_file=dot_file, filled=True,
               rounded=True)

image=pydotplus.graph_from_dot_data(dot_file.getvalue())
Image(image.create_png())

# %% [markdown]
# ## Interpretation
#
# Let's unpack this:
#
# - The first question ("test") is: "Is Age $\leq$ 34.5?" If so, then stop: All such customers (i.e. customers 0 and 2) are *non-payers*. Notice how 34.5 is midway between the ages of customer 2 (25), a non-payer and customer 3 (44), a payer).
#
# - If not: The next test (for those whose age > 34.5) is: "Is Salary $\leq$ 80000?" If not, then stop: All such customers (i.e. customer 3) are *payers*. Notice how 80000 is midway between the salaries of customer 3 (90000, a payer) and customer 4 (70000, a non-payer).
#
# - If so: The next test (for those whose salary $\leq$ 80000) is: "Is Age $\leq$ 49.0?" If so, then stop: All such customers (i.e. customer 4) are *non-payers*. If not, then stop: All such customers (i.e. customer 1) are *payers*. Notice how 49.0 is midway between the ages of customer 1 (50, a payer) and customer 4 (48, a non-payer).

# %% [markdown]
# ## Feature Importances
#
# The fitted tree has an attribute called `ct.feature_importances_`. What does this mean? Roughly, the importance (or "Gini importance") of a feature is a sort of weighted average of the impurity decrease at internal nodes that make use of the feature. The weighting comes from the number of samples that depend on the relevant nodes.

# %%
ct.feature_importances_
# Out:
# array([0.15549452, 0.        , 0.        , 0.84450548])

# %% [markdown]
# Let's see if we can calculate these by hand:

# %%
# Entropies at Internal Nodes:
n0_ent = -(0.6 * log(0.6, 2) + 0.4 * log(0.4, 2))
n2_ent = -((2/3) * log((2/3), 2) + (1/3) * log((1/3), 2))
n3_ent = -(0.5 * log(0.5, 2) + 0.5 * log(0.5, 2))

# Node Importances
n0_imp = n0_ent - 0.6 * n2_ent
n2_imp = 0.6 * n2_ent - 0.4 * n3_ent
n3_imp = 0.4 * n3_ent

# %%
n_imp_sum = n0_imp + n2_imp + n3_imp

# %%
n2_imp / n_imp_sum
# Out:
# 0.15549452391806784

# %%
(n0_imp + n3_imp) / n_imp_sum
# Out:
# 0.8445054760819322

# %% [markdown]
# See [here](https://towardsdatascience.com/the-mathematics-of-decision-trees-random-forest-and-feature-importance-in-scikit-learn-and-spark-f2861df67e3) for more on feature importances.

# %% [markdown]
# ## Practice on a Larger Dataset
#
# Exercise: Use a tree for prediction. Using the data below, use height and weight to predict gender.
#
# Make a visualization or two, and write a short paragraph about your findings.

# %%
from sklearn.model_selection import train_test_split

# %%
wts_hts = pd.read_csv('weight-height.csv')

# %%
wts_hts.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
X_train, X_test, y_train, y_test = train_test_split(wts_hts.drop('Gender', axis=1), wts_hts['Gender'])

# %%
# Your code here
ct = DecisionTreeClassifier(criterion='entropy')
ct.fit(X_train, y_train)
ct.score(X_train, y_train)

describe_tree(ct)
# Out:
# The binary tree structure has 1529 nodes and has the following tree structure:
# node=0 test node: go to node 1 if X[:, 1] <= 162.7932891845703 else to node 866.
# 	node=1 test node: go to node 2 if X[:, 1] <= 145.68144989013672 else to node 251.
# 		node=2 test node: go to node 3 if X[:, 1] <= 134.8208999633789 else to node 64.
# 			node=3 test node: go to node 4 if X[:, 1] <= 119.2361831665039 else to node 9.
# 				node=4 test node: go to node 5 if X[:, 0] <= 59.98978042602539 else to node 8.
# 					node=5 test node: go to node 6 if X[:, 0] <= 59.98041343688965 else to node 7.
# 						node=6 leaf node.
# 						node=7 leaf node.
# 					node=8 leaf node.
# 				node=9 test node: go to node 10 if X[:, 0] <= 62.259681701660156 else to node 53.
# 					node=10 test node: go to node 11 if X[:, 0] <= 62.255882263183594 else to node 52.
# 						node=11 test node: go to node 12 if X[:, 0] <= 58.465097427368164 else to node 15.
# 							node=12 test node: go to node 13 if X[:, 0] <= 58.04104423522949 else to node 14.
# 								node=13 leaf node.
# 								node=14 leaf node.
# 							node=15 test node: go to node 16 if X[:, 1] <= 122.67708206176758 else to node 17.
# 								node=16 leaf node.
# 								node=17 test node: go to node 18 if X[:, 1] <= 122.69445037841797 else to node 19.
# 									node=18 leaf node.
# 									node=19 test node: go to node 20 if X[:, 0] <= 60.25974082946777 else to node 21.
# 										node=20 leaf node.
# 										node=21 test node: go to node 22 if X[:, 0] <= 60.28627586364746 else to node 23.
# 											node=22 leaf node.
# 											node=23 test node: go to node 24 if X[:, 1] <= 130.88997650146484 else to node 51.
# 												node=24 test node: go to node 25 if X[:, 1] <= 130.82150268554688 else to node 50.
# 													node=25 test node: go to node 26 if X[:, 1] <= 128.3305435180664 else to node 39.
# 														node=26 test node: go to node 27 if X[:, 1] <= 123.6327896118164 else to node 34.
# 															node=27 test node: go to node 28 if X[:, 1] <= 123.47414016723633 else to node 29.
# 																node=28 leaf node.
# 																node=29 test node: go to node 30 if X[:, 0] <= 60.92059898376465 else to node 31.
# 																	node=30 leaf node.
# 																	node=31 test node: go to node 32 if X[:, 0] <= 61.438026428222656 else to node 33.
# 																		node=32 leaf node.
# 																		node=33 leaf node.
# 															node=34 test node: go to node 35 if X[:, 0] <= 61.140037536621094 else to node 38.
# 																node=35 test node: go to node 36 if X[:, 0] <= 61.11142539978027 else to node 37.
# 																	node=36 leaf node.
# 																	node=37 leaf node.
# 																node=38 leaf node.
# 														node=39 test node: go to node 40 if X[:, 1] <= 128.4173812866211 else to node 41.
# 															node=40 leaf node.
# 															node=41 test node: go to node 42 if X[:, 0] <= 61.46953582763672 else to node 43.
# 																node=42 leaf node.
# 																node=43 test node: go to node 44 if X[:, 0] <= 61.499624252319336 else to node 45.
# 																	node=44 leaf node.
# 																	node=45 test node: go to node 46 if X[:, 1] <= 130.1447982788086 else to node 47.
# 																		node=46 leaf node.
# 																		node=47 test node: go to node 48 if X[:, 1] <= 130.2885284423828 else to node 49.
# 																			node=48 leaf node.
# 																			node=49 leaf node.
# 													node=50 leaf node.
# 												node=51 leaf node.
# 						node=52 leaf node.
# 					node=53 test node: go to node 54 if X[:, 1] <= 119.27942276000977 else to node 55.
# 						node=54 leaf node.
# 						node=55 test node: go to node 56 if X[:, 1] <= 131.79828643798828 else to node 57.
# 							node=56 leaf node.
# 							node=57 test node: go to node 58 if X[:, 1] <= 131.80123901367188 else to node 59.
# 								node=58 leaf node.
# 								node=59 test node: go to node 60 if X[:, 0] <= 64.92809677124023 else to node 61.
# 									node=60 leaf node.
# 									node=61 test node: go to node 62 if X[:, 0] <= 64.95354080200195 else to node 63.
# 										node=62 leaf node.
# 										node=63 leaf node.
# 			node=64 test node: go to node 65 if X[:, 0] <= 61.976030349731445 else to node 110.
# 				node=65 test node: go to node 66 if X[:, 0] <= 61.6734676361084 else to node 91.
# 					node=66 test node: go to node 67 if X[:, 0] <= 60.00744438171387 else to node 72.
# 						node=67 test node: go to node 68 if X[:, 1] <= 137.95956420898438 else to node 69.
# 							node=68 leaf node.
# 							node=69 test node: go to node 70 if X[:, 1] <= 140.4938507080078 else to node 71.
# 								node=70 leaf node.
# 								node=71 leaf node.
# 						node=72 test node: go to node 73 if X[:, 1] <= 134.88904571533203 else to node 74.
# 							node=73 leaf node.
# 							node=74 test node: go to node 75 if X[:, 1] <= 139.86389923095703 else to node 90.
# 								node=75 test node: go to node 76 if X[:, 0] <= 61.60585975646973 else to node 89.
# 									node=76 test node: go to node 77 if X[:, 1] <= 139.81009674072266 else to node 88.
# 										node=77 test node: go to node 78 if X[:, 0] <= 60.8328914642334 else to node 83.
# 											node=78 test node: go to node 79 if X[:, 0] <= 60.69118309020996 else to node 80.
# 												node=79 leaf node.
# 												node=80 test node: go to node 81 if X[:, 1] <= 137.7900619506836 else to node 82.
# 													node=81 leaf node.
# 													node=82 leaf node.
# 											node=83 test node: go to node 84 if X[:, 1] <= 135.55633544921875 else to node 87.
# 												node=84 test node: go to node 85 if X[:, 1] <= 135.46826171875 else to node 86.
# 													node=85 leaf node.
# 													node=86 leaf node.
# 												node=87 leaf node.
# 										node=88 leaf node.
# 									node=89 leaf node.
# 								node=90 leaf node.
# 					node=91 test node: go to node 92 if X[:, 0] <= 61.7454833984375 else to node 93.
# 						node=92 leaf node.
# 						node=93 test node: go to node 94 if X[:, 0] <= 61.96789360046387 else to node 109.
# 							node=94 test node: go to node 95 if X[:, 1] <= 135.58883666992188 else to node 96.
# 								node=95 leaf node.
# 								node=96 test node: go to node 97 if X[:, 0] <= 61.793222427368164 else to node 98.
# 									node=97 leaf node.
# 									node=98 test node: go to node 99 if X[:, 0] <= 61.79860305786133 else to node 100.
# 										node=99 leaf node.
# 										node=100 test node: go to node 101 if X[:, 1] <= 139.69271087646484 else to node 102.
# 											node=101 leaf node.
# 											node=102 test node: go to node 103 if X[:, 1] <= 140.92196655273438 else to node 104.
# 												node=103 leaf node.
# 												node=104 test node: go to node 105 if X[:, 1] <= 142.91317749023438 else to node 106.
# 													node=105 leaf node.
# 													node=106 test node: go to node 107 if X[:, 1] <= 143.98847198486328 else to node 108.
# 														node=107 leaf node.
# 														node=108 leaf node.
# 							node=109 leaf node.
# 				node=110 test node: go to node 111 if X[:, 0] <= 65.44303512573242 else to node 242.
# 					node=111 test node: go to node 112 if X[:, 0] <= 65.40896606445312 else to node 235.
# 						node=112 test node: go to node 113 if X[:, 1] <= 144.54288482666016 else to node 210.
# 							node=113 test node: go to node 114 if X[:, 0] <= 63.977928161621094 else to node 177.
# 								node=114 test node: go to node 115 if X[:, 0] <= 63.95574378967285 else to node 172.
# 									node=115 test node: go to node 116 if X[:, 1] <= 139.13021850585938 else to node 137.
# 										node=116 test node: go to node 117 if X[:, 0] <= 62.78501892089844 else to node 118.
# 											node=117 leaf node.
# 											node=118 test node: go to node 119 if X[:, 0] <= 63.44174766540527 else to node 136.
# 												node=119 test node: go to node 120 if X[:, 0] <= 62.798240661621094 else to node 121.
# 													node=120 leaf node.
# 													node=121 test node: go to node 122 if X[:, 0] <= 63.43887138366699 else to node 135.
# 														node=122 test node: go to node 123 if X[:, 0] <= 63.3298282623291 else to node 128.
# 															node=123 test node: go to node 124 if X[:, 1] <= 135.70276641845703 else to node 127.
# 																node=124 test node: go to node 125 if X[:, 1] <= 135.609130859375 else to node 126.
# 																	node=125 leaf node.
# 																	node=126 leaf node.
# 																node=127 leaf node.
# 															node=128 test node: go to node 129 if X[:, 0] <= 63.333879470825195 else to node 130.
# 																node=129 leaf node.
# 																node=130 test node: go to node 131 if X[:, 0] <= 63.383649826049805 else to node 132.
# 																	node=131 leaf node.
# 																	node=132 test node: go to node 133 if X[:, 0] <= 63.407901763916016 else to node 134.
# 																		node=133 leaf node.
# 																		node=134 leaf node.
# 														node=135 leaf node.
# 												node=136 leaf node.
# 										node=137 test node: go to node 138 if X[:, 1] <= 142.28729248046875 else to node 167.
# 											node=138 test node: go to node 139 if X[:, 1] <= 142.1572723388672 else to node 162.
# 												node=139 test node: go to node 140 if X[:, 1] <= 139.13544464111328 else to node 141.
# 													node=140 leaf node.
# 													node=141 test node: go to node 142 if X[:, 1] <= 139.40575408935547 else to node 143.
# 														node=142 leaf node.
# 														node=143 test node: go to node 144 if X[:, 1] <= 140.56774139404297 else to node 157.
# 															node=144 test node: go to node 145 if X[:, 1] <= 140.46060943603516 else to node 156.
# 																node=145 test node: go to node 146 if X[:, 1] <= 139.43155670166016 else to node 147.
# 																	node=146 leaf node.
# 																	node=147 test node: go to node 148 if X[:, 1] <= 139.8765640258789 else to node 149.
# 																		node=148 leaf node.
# 																		node=149 test node: go to node 150 if X[:, 0] <= 62.81379318237305 else to node 151.
# 																			node=150 leaf node.
# 																			node=151 test node: go to node 152 if X[:, 1] <= 139.9551544189453 else to node 153.
# 																				node=152 leaf node.
# 																				node=153 test node: go to node 154 if X[:, 0] <= 63.87285232543945 else to node 155.
# 																					node=154 leaf node.
# 																					node=155 leaf node.
# 																node=156 leaf node.
# 															node=157 test node: go to node 158 if X[:, 0] <= 63.36123275756836 else to node 159.
# 																node=158 leaf node.
# 																node=159 test node: go to node 160 if X[:, 0] <= 63.417945861816406 else to node 161.
# 																	node=160 leaf node.
# 																	node=161 leaf node.
# 												node=162 test node: go to node 163 if X[:, 0] <= 62.96063423156738 else to node 166.
# 													node=163 test node: go to node 164 if X[:, 0] <= 62.45284843444824 else to node 165.
# 														node=164 leaf node.
# 														node=165 leaf node.
# 													node=166 leaf node.
# 											node=167 test node: go to node 168 if X[:, 1] <= 144.12167358398438 else to node 169.
# 												node=168 leaf node.
# 												node=169 test node: go to node 170 if X[:, 1] <= 144.18505859375 else to node 171.
# 													node=170 leaf node.
# 													node=171 leaf node.
# 									node=172 test node: go to node 173 if X[:, 0] <= 63.96001625061035 else to node 174.
# 										node=173 leaf node.
# 										node=174 test node: go to node 175 if X[:, 0] <= 63.96961975097656 else to node 176.
# 											node=175 leaf node.
# 											node=176 leaf node.
# 								node=177 test node: go to node 178 if X[:, 1] <= 140.52147674560547 else to node 205.
# 									node=178 test node: go to node 179 if X[:, 1] <= 140.50908660888672 else to node 204.
# 										node=179 test node: go to node 180 if X[:, 0] <= 64.2158088684082 else to node 181.
# 											node=180 leaf node.
# 											node=181 test node: go to node 182 if X[:, 0] <= 64.23906326293945 else to node 183.
# 												node=182 leaf node.
# 												node=183 test node: go to node 184 if X[:, 0] <= 65.13734817504883 else to node 203.
# 													node=184 test node: go to node 185 if X[:, 0] <= 65.1317253112793 else to node 202.
# 														node=185 test node: go to node 186 if X[:, 0] <= 64.43951797485352 else to node 187.
# 															node=186 leaf node.
# 															node=187 test node: go to node 188 if X[:, 0] <= 64.44630813598633 else to node 189.
# 																node=188 leaf node.
# 																node=189 test node: go to node 190 if X[:, 0] <= 64.59566497802734 else to node 191.
# 																	node=190 leaf node.
# 																	node=191 test node: go to node 192 if X[:, 0] <= 64.60247802734375 else to node 193.
# 																		node=192 leaf node.
# 																		node=193 test node: go to node 194 if X[:, 0] <= 64.63010025024414 else to node 197.
# 																			node=194 test node: go to node 195 if X[:, 0] <= 64.62534713745117 else to node 196.
# 																				node=195 leaf node.
# 																				node=196 leaf node.
# 																			node=197 test node: go to node 198 if X[:, 1] <= 138.88912963867188 else to node 199.
# 																				node=198 leaf node.
# 																				node=199 test node: go to node 200 if X[:, 1] <= 138.96161651611328 else to node 201.
# 																					node=200 leaf node.
# 																					node=201 leaf node.
# 														node=202 leaf node.
# 													node=203 leaf node.
# 										node=204 leaf node.
# 									node=205 test node: go to node 206 if X[:, 1] <= 143.34613037109375 else to node 207.
# 										node=206 leaf node.
# 										node=207 test node: go to node 208 if X[:, 1] <= 143.35570526123047 else to node 209.
# 											node=208 leaf node.
# 											node=209 leaf node.
# 							node=210 test node: go to node 211 if X[:, 1] <= 144.5927505493164 else to node 212.
# 								node=211 leaf node.
# 								node=212 test node: go to node 213 if X[:, 1] <= 145.40116119384766 else to node 234.
# 									node=213 test node: go to node 214 if X[:, 1] <= 145.37435150146484 else to node 233.
# 										node=214 test node: go to node 215 if X[:, 0] <= 63.60246276855469 else to node 224.
# 											node=215 test node: go to node 216 if X[:, 1] <= 144.8786849975586 else to node 223.
# 												node=216 test node: go to node 217 if X[:, 1] <= 144.73751831054688 else to node 220.
# 													node=217 test node: go to node 218 if X[:, 1] <= 144.6632080078125 else to node 219.
# 														node=218 leaf node.
# 														node=219 leaf node.
# 													node=220 test node: go to node 221 if X[:, 0] <= 62.2992000579834 else to node 222.
# 														node=221 leaf node.
# 														node=222 leaf node.
# 												node=223 leaf node.
# 											node=224 test node: go to node 225 if X[:, 1] <= 145.1742172241211 else to node 226.
# 												node=225 leaf node.
# 												node=226 test node: go to node 227 if X[:, 1] <= 145.2064666748047 else to node 228.
# 													node=227 leaf node.
# 													node=228 test node: go to node 229 if X[:, 0] <= 65.21627807617188 else to node 230.
# 														node=229 leaf node.
# 														node=230 test node: go to node 231 if X[:, 0] <= 65.26349639892578 else to node 232.
# 															node=231 leaf node.
# 															node=232 leaf node.
# 										node=233 leaf node.
# 									node=234 leaf node.
# 						node=235 test node: go to node 236 if X[:, 1] <= 142.5220947265625 else to node 237.
# 							node=236 leaf node.
# 							node=237 test node: go to node 238 if X[:, 0] <= 65.41676330566406 else to node 239.
# 								node=238 leaf node.
# 								node=239 test node: go to node 240 if X[:, 1] <= 143.42941284179688 else to node 241.
# 									node=240 leaf node.
# 									node=241 leaf node.
# 					node=242 test node: go to node 243 if X[:, 0] <= 66.75519180297852 else to node 244.
# 						node=243 leaf node.
# 						node=244 test node: go to node 245 if X[:, 0] <= 66.76468658447266 else to node 246.
# 							node=245 leaf node.
# 							node=246 test node: go to node 247 if X[:, 1] <= 144.15838623046875 else to node 248.
# 								node=247 leaf node.
# 								node=248 test node: go to node 249 if X[:, 1] <= 144.2921905517578 else to node 250.
# 									node=249 leaf node.
# 									node=250 leaf node.
# 		node=251 test node: go to node 252 if X[:, 1] <= 153.8292007446289 else to node 497.
# 			node=252 test node: go to node 253 if X[:, 0] <= 63.04048156738281 else to node 292.
# 				node=253 test node: go to node 254 if X[:, 0] <= 61.404876708984375 else to node 255.
# 					node=254 leaf node.
# 					node=255 test node: go to node 256 if X[:, 1] <= 147.82172393798828 else to node 267.
# 						node=256 test node: go to node 257 if X[:, 1] <= 146.41627502441406 else to node 266.
# 							node=257 test node: go to node 258 if X[:, 1] <= 145.72052764892578 else to node 259.
# 								node=258 leaf node.
# 								node=259 test node: go to node 260 if X[:, 1] <= 146.3121795654297 else to node 265.
# 									node=260 test node: go to node 261 if X[:, 1] <= 145.7812957763672 else to node 264.
# 										node=261 test node: go to node 262 if X[:, 1] <= 145.75745391845703 else to node 263.
# 											node=262 leaf node.
# 											node=263 leaf node.
# 										node=264 leaf node.
# 									node=265 leaf node.
# 							node=266 leaf node.
# 						node=267 test node: go to node 268 if X[:, 0] <= 62.98072624206543 else to node 291.
# 							node=268 test node: go to node 269 if X[:, 0] <= 62.830156326293945 else to node 286.
# 								node=269 test node: go to node 270 if X[:, 0] <= 62.68873977661133 else to node 285.
# 									node=270 test node: go to node 271 if X[:, 1] <= 153.0696029663086 else to node 284.
# 										node=271 test node: go to node 272 if X[:, 1] <= 151.67122650146484 else to node 283.
# 											node=272 test node: go to node 273 if X[:, 1] <= 150.89907836914062 else to node 282.
# 												node=273 test node: go to node 274 if X[:, 1] <= 149.2116241455078 else to node 281.
# 													node=274 test node: go to node 275 if X[:, 1] <= 147.91226959228516 else to node 276.
# 														node=275 leaf node.
# 														node=276 test node: go to node 277 if X[:, 1] <= 148.83776092529297 else to node 278.
# 															node=277 leaf node.
# 															node=278 test node: go to node 279 if X[:, 1] <= 149.17082977294922 else to node 280.
# 																node=279 leaf node.
# 																node=280 leaf node.
# 													node=281 leaf node.
# 												node=282 leaf node.
# 											node=283 leaf node.
# 										node=284 leaf node.
# 									node=285 leaf node.
# 								node=286 test node: go to node 287 if X[:, 0] <= 62.939720153808594 else to node 288.
# 									node=287 leaf node.
# 									node=288 test node: go to node 289 if X[:, 1] <= 150.6267318725586 else to node 290.
# 										node=289 leaf node.
# 										node=290 leaf node.
# 							node=291 leaf node.
# 				node=292 test node: go to node 293 if X[:, 0] <= 66.36444854736328 else to node 480.
# 					node=293 test node: go to node 294 if X[:, 0] <= 66.35199356079102 else to node 479.
# 						node=294 test node: go to node 295 if X[:, 0] <= 64.61516952514648 else to node 378.
# 							node=295 test node: go to node 296 if X[:, 1] <= 151.9881591796875 else to node 355.
# 								node=296 test node: go to node 297 if X[:, 1] <= 147.08590698242188 else to node 310.
# 									node=297 test node: go to node 298 if X[:, 0] <= 64.04719161987305 else to node 299.
# 										node=298 leaf node.
# 										node=299 test node: go to node 300 if X[:, 0] <= 64.08158111572266 else to node 301.
# 											node=300 leaf node.
# 											node=301 test node: go to node 302 if X[:, 0] <= 64.43545150756836 else to node 309.
# 												node=302 test node: go to node 303 if X[:, 0] <= 64.39425659179688 else to node 308.
# 													node=303 test node: go to node 304 if X[:, 0] <= 64.14688873291016 else to node 307.
# 														node=304 test node: go to node 305 if X[:, 0] <= 64.11481475830078 else to node 306.
# 															node=305 leaf node.
# 															node=306 leaf node.
# 														node=307 leaf node.
# 													node=308 leaf node.
# 												node=309 leaf node.
# 									node=310 test node: go to node 311 if X[:, 1] <= 147.50537109375 else to node 318.
# 										node=311 test node: go to node 312 if X[:, 0] <= 64.17781448364258 else to node 317.
# 											node=312 test node: go to node 313 if X[:, 1] <= 147.28137969970703 else to node 316.
# 												node=313 test node: go to node 314 if X[:, 0] <= 63.718435287475586 else to node 315.
# 													node=314 leaf node.
# 													node=315 leaf node.
# 												node=316 leaf node.
# 											node=317 leaf node.
# 										node=318 test node: go to node 319 if X[:, 0] <= 64.51455307006836 else to node 348.
# 											node=319 test node: go to node 320 if X[:, 0] <= 64.36433792114258 else to node 347.
# 												node=320 test node: go to node 321 if X[:, 0] <= 64.3425178527832 else to node 346.
# 													node=321 test node: go to node 322 if X[:, 0] <= 64.09356689453125 else to node 345.
# 														node=322 test node: go to node 323 if X[:, 0] <= 63.827505111694336 else to node 332.
# 															node=323 test node: go to node 324 if X[:, 0] <= 63.55189323425293 else to node 331.
# 																node=324 test node: go to node 325 if X[:, 0] <= 63.51319122314453 else to node 330.
# 																	node=325 test node: go to node 326 if X[:, 0] <= 63.187259674072266 else to node 329.
# 																		node=326 test node: go to node 327 if X[:, 0] <= 63.18331527709961 else to node 328.
# 																			node=327 leaf node.
# 																			node=328 leaf node.
# 																		node=329 leaf node.
# 																	node=330 leaf node.
# 																node=331 leaf node.
# 															node=332 test node: go to node 333 if X[:, 0] <= 63.84736633300781 else to node 334.
# 																node=333 leaf node.
# 																node=334 test node: go to node 335 if X[:, 1] <= 150.67823028564453 else to node 340.
# 																	node=335 test node: go to node 336 if X[:, 0] <= 63.952369689941406 else to node 339.
# 																		node=336 test node: go to node 337 if X[:, 0] <= 63.93593215942383 else to node 338.
# 																			node=337 leaf node.
# 																			node=338 leaf node.
# 																		node=339 leaf node.
# 																	node=340 test node: go to node 341 if X[:, 1] <= 151.32134246826172 else to node 342.
# 																		node=341 leaf node.
# 																		node=342 test node: go to node 343 if X[:, 1] <= 151.57723236083984 else to node 344.
# 																			node=343 leaf node.
# 																			node=344 leaf node.
# 														node=345 leaf node.
# 													node=346 leaf node.
# 												node=347 leaf node.
# 											node=348 test node: go to node 349 if X[:, 1] <= 150.19473266601562 else to node 354.
# 												node=349 test node: go to node 350 if X[:, 1] <= 148.71314239501953 else to node 353.
# 													node=350 test node: go to node 351 if X[:, 0] <= 64.53008270263672 else to node 352.
# 														node=351 leaf node.
# 														node=352 leaf node.
# 													node=353 leaf node.
# 												node=354 leaf node.
# 								node=355 test node: go to node 356 if X[:, 1] <= 152.87181091308594 else to node 365.
# 									node=356 test node: go to node 357 if X[:, 0] <= 64.30575942993164 else to node 364.
# 										node=357 test node: go to node 358 if X[:, 0] <= 63.81785774230957 else to node 363.
# 											node=358 test node: go to node 359 if X[:, 0] <= 63.73068809509277 else to node 362.
# 												node=359 test node: go to node 360 if X[:, 1] <= 152.63521575927734 else to node 361.
# 													node=360 leaf node.
# 													node=361 leaf node.
# 												node=362 leaf node.
# 											node=363 leaf node.
# 										node=364 leaf node.
# 									node=365 test node: go to node 366 if X[:, 1] <= 153.0721664428711 else to node 367.
# 										node=366 leaf node.
# 										node=367 test node: go to node 368 if X[:, 0] <= 64.20986557006836 else to node 373.
# 											node=368 test node: go to node 369 if X[:, 0] <= 63.301673889160156 else to node 372.
# 												node=369 test node: go to node 370 if X[:, 0] <= 63.14072227478027 else to node 371.
# 													node=370 leaf node.
# 													node=371 leaf node.
# 												node=372 leaf node.
# 											node=373 test node: go to node 374 if X[:, 0] <= 64.55076599121094 else to node 375.
# 												node=374 leaf node.
# 												node=375 test node: go to node 376 if X[:, 0] <= 64.59088516235352 else to node 377.
# 													node=376 leaf node.
# 													node=377 leaf node.
# 							node=378 test node: go to node 379 if X[:, 0] <= 64.91353225708008 else to node 388.
# 								node=379 test node: go to node 380 if X[:, 1] <= 150.68132781982422 else to node 387.
# 									node=380 test node: go to node 381 if X[:, 1] <= 150.5900650024414 else to node 386.
# 										node=381 test node: go to node 382 if X[:, 0] <= 64.81514358520508 else to node 383.
# 											node=382 leaf node.
# 											node=383 test node: go to node 384 if X[:, 0] <= 64.82812881469727 else to node 385.
# 												node=384 leaf node.
# 												node=385 leaf node.
# 										node=386 leaf node.
# 									node=387 leaf node.
# 								node=388 test node: go to node 389 if X[:, 1] <= 153.1333770751953 else to node 478.
# 									node=389 test node: go to node 390 if X[:, 1] <= 146.37451171875 else to node 401.
# 										node=390 test node: go to node 391 if X[:, 0] <= 66.13409805297852 else to node 400.
# 											node=391 test node: go to node 392 if X[:, 0] <= 65.51397323608398 else to node 399.
# 												node=392 test node: go to node 393 if X[:, 0] <= 64.96893692016602 else to node 394.
# 													node=393 leaf node.
# 													node=394 test node: go to node 395 if X[:, 1] <= 146.1034393310547 else to node 396.
# 														node=395 leaf node.
# 														node=396 test node: go to node 397 if X[:, 1] <= 146.17816162109375 else to node 398.
# 															node=397 leaf node.
# 															node=398 leaf node.
# 												node=399 leaf node.
# 											node=400 leaf node.
# 										node=401 test node: go to node 402 if X[:, 0] <= 65.20858383178711 else to node 435.
# 											node=402 test node: go to node 403 if X[:, 1] <= 152.51227569580078 else to node 432.
# 												node=403 test node: go to node 404 if X[:, 0] <= 65.18386840820312 else to node 425.
# 													node=404 test node: go to node 405 if X[:, 1] <= 148.8563232421875 else to node 406.
# 														node=405 leaf node.
# 														node=406 test node: go to node 407 if X[:, 1] <= 149.46400451660156 else to node 416.
# 															node=407 test node: go to node 408 if X[:, 1] <= 149.2590103149414 else to node 415.
# 																node=408 test node: go to node 409 if X[:, 1] <= 149.1349105834961 else to node 414.
# 																	node=409 test node: go to node 410 if X[:, 0] <= 64.98059463500977 else to node 411.
# 																		node=410 leaf node.
# 																		node=411 test node: go to node 412 if X[:, 1] <= 149.0496063232422 else to node 413.
# 																			node=412 leaf node.
# 																			node=413 leaf node.
# 																	node=414 leaf node.
# 																node=415 leaf node.
# 															node=416 test node: go to node 417 if X[:, 1] <= 150.52452087402344 else to node 418.
# 																node=417 leaf node.
# 																node=418 test node: go to node 419 if X[:, 1] <= 150.64907836914062 else to node 420.
# 																	node=419 leaf node.
# 																	node=420 test node: go to node 421 if X[:, 0] <= 64.9868278503418 else to node 424.
# 																		node=421 test node: go to node 422 if X[:, 0] <= 64.95870208740234 else to node 423.
# 																			node=422 leaf node.
# 																			node=423 leaf node.
# 																		node=424 leaf node.
# 													node=425 test node: go to node 426 if X[:, 1] <= 152.19335174560547 else to node 431.
# 														node=426 test node: go to node 427 if X[:, 0] <= 65.19946670532227 else to node 428.
# 															node=427 leaf node.
# 															node=428 test node: go to node 429 if X[:, 1] <= 149.9768829345703 else to node 430.
# 																node=429 leaf node.
# 																node=430 leaf node.
# 														node=431 leaf node.
# 												node=432 test node: go to node 433 if X[:, 0] <= 64.96282577514648 else to node 434.
# 													node=433 leaf node.
# 													node=434 leaf node.
# 											node=435 test node: go to node 436 if X[:, 1] <= 152.9382781982422 else to node 473.
# 												node=436 test node: go to node 437 if X[:, 1] <= 151.6713409423828 else to node 472.
# 													node=437 test node: go to node 438 if X[:, 1] <= 151.6164779663086 else to node 471.
# 														node=438 test node: go to node 439 if X[:, 1] <= 147.99827575683594 else to node 444.
# 															node=439 test node: go to node 440 if X[:, 0] <= 65.37188339233398 else to node 443.
# 																node=440 test node: go to node 441 if X[:, 1] <= 146.74612426757812 else to node 442.
# 																	node=441 leaf node.
# 																	node=442 leaf node.
# 																node=443 leaf node.
# 															node=444 test node: go to node 445 if X[:, 1] <= 148.41661834716797 else to node 448.
# 																node=445 test node: go to node 446 if X[:, 0] <= 65.70738983154297 else to node 447.
# 																	node=446 leaf node.
# 																	node=447 leaf node.
# 																node=448 test node: go to node 449 if X[:, 1] <= 149.92743682861328 else to node 450.
# 																	node=449 leaf node.
# 																	node=450 test node: go to node 451 if X[:, 1] <= 150.296630859375 else to node 462.
# 																		node=451 test node: go to node 452 if X[:, 0] <= 66.27616500854492 else to node 461.
# 																			node=452 test node: go to node 453 if X[:, 1] <= 149.94927978515625 else to node 454.
# 																				node=453 leaf node.
# 																				node=454 test node: go to node 455 if X[:, 1] <= 150.28187561035156 else to node 460.
# 																					node=455 test node: go to node 456 if X[:, 0] <= 66.05739974975586 else to node 457.
# 																						node=456 leaf node.
# 																						node=457 test node: go to node 458 if X[:, 1] <= 150.0599594116211 else to node 459.
# 																							node=458 leaf node.
# 																							node=459 leaf node.
# 																					node=460 leaf node.
# 																			node=461 leaf node.
# 																		node=462 test node: go to node 463 if X[:, 0] <= 65.67512893676758 else to node 464.
# 																			node=463 leaf node.
# 																			node=464 test node: go to node 465 if X[:, 0] <= 65.94733428955078 else to node 470.
# 																				node=465 test node: go to node 466 if X[:, 1] <= 150.71973419189453 else to node 467.
# 																					node=466 leaf node.
# 																					node=467 test node: go to node 468 if X[:, 1] <= 151.4707794189453 else to node 469.
# 																						node=468 leaf node.
# 																						node=469 leaf node.
# 																				node=470 leaf node.
# 														node=471 leaf node.
# 													node=472 leaf node.
# 												node=473 test node: go to node 474 if X[:, 0] <= 65.83164596557617 else to node 475.
# 													node=474 leaf node.
# 													node=475 test node: go to node 476 if X[:, 1] <= 153.07909393310547 else to node 477.
# 														node=476 leaf node.
# 														node=477 leaf node.
# 									node=478 leaf node.
# 						node=479 leaf node.
# 					node=480 test node: go to node 481 if X[:, 1] <= 152.16858673095703 else to node 482.
# 						node=481 leaf node.
# 						node=482 test node: go to node 483 if X[:, 0] <= 67.08528900146484 else to node 484.
# 							node=483 leaf node.
# 							node=484 test node: go to node 485 if X[:, 0] <= 67.16820907592773 else to node 486.
# 								node=485 leaf node.
# 								node=486 test node: go to node 487 if X[:, 1] <= 153.0649871826172 else to node 494.
# 									node=487 test node: go to node 488 if X[:, 0] <= 68.06966018676758 else to node 493.
# 										node=488 test node: go to node 489 if X[:, 0] <= 67.79532623291016 else to node 492.
# 											node=489 test node: go to node 490 if X[:, 1] <= 152.28858947753906 else to node 491.
# 												node=490 leaf node.
# 												node=491 leaf node.
# 											node=492 leaf node.
# 										node=493 leaf node.
# 									node=494 test node: go to node 495 if X[:, 0] <= 68.80132293701172 else to node 496.
# 										node=495 leaf node.
# 										node=496 leaf node.
# 			node=497 test node: go to node 498 if X[:, 0] <= 65.57267761230469 else to node 667.
# 				node=498 test node: go to node 499 if X[:, 1] <= 156.24964141845703 else to node 550.
# 					node=499 test node: go to node 500 if X[:, 0] <= 64.18333435058594 else to node 519.
# 						node=500 test node: go to node 501 if X[:, 0] <= 63.84403038024902 else to node 518.
# 							node=501 test node: go to node 502 if X[:, 0] <= 62.9705810546875 else to node 503.
# 								node=502 leaf node.
# 								node=503 test node: go to node 504 if X[:, 1] <= 154.61643981933594 else to node 509.
# 									node=504 test node: go to node 505 if X[:, 1] <= 154.13487243652344 else to node 508.
# 										node=505 test node: go to node 506 if X[:, 0] <= 63.67610740661621 else to node 507.
# 											node=506 leaf node.
# 											node=507 leaf node.
# 										node=508 leaf node.
# 									node=509 test node: go to node 510 if X[:, 1] <= 154.9005584716797 else to node 511.
# 										node=510 leaf node.
# 										node=511 test node: go to node 512 if X[:, 1] <= 155.04981994628906 else to node 513.
# 											node=512 leaf node.
# 											node=513 test node: go to node 514 if X[:, 0] <= 63.5429744720459 else to node 517.
# 												node=514 test node: go to node 515 if X[:, 1] <= 156.06731414794922 else to node 516.
# 													node=515 leaf node.
# 													node=516 leaf node.
# 												node=517 leaf node.
# 							node=518 leaf node.
# 						node=519 test node: go to node 520 if X[:, 1] <= 154.1720733642578 else to node 521.
# 							node=520 leaf node.
# 							node=521 test node: go to node 522 if X[:, 1] <= 154.58554077148438 else to node 523.
# 								node=522 leaf node.
# 								node=523 test node: go to node 524 if X[:, 1] <= 156.0847396850586 else to node 549.
# 									node=524 test node: go to node 525 if X[:, 0] <= 65.17093658447266 else to node 540.
# 										node=525 test node: go to node 526 if X[:, 0] <= 64.7345199584961 else to node 535.
# 											node=526 test node: go to node 527 if X[:, 1] <= 155.61888122558594 else to node 534.
# 												node=527 test node: go to node 528 if X[:, 1] <= 154.7472686767578 else to node 529.
# 													node=528 leaf node.
# 													node=529 test node: go to node 530 if X[:, 0] <= 64.31293869018555 else to node 533.
# 														node=530 test node: go to node 531 if X[:, 1] <= 155.3712921142578 else to node 532.
# 															node=531 leaf node.
# 															node=532 leaf node.
# 														node=533 leaf node.
# 												node=534 leaf node.
# 											node=535 test node: go to node 536 if X[:, 1] <= 154.8488540649414 else to node 539.
# 												node=536 test node: go to node 537 if X[:, 1] <= 154.8033905029297 else to node 538.
# 													node=537 leaf node.
# 													node=538 leaf node.
# 												node=539 leaf node.
# 										node=540 test node: go to node 541 if X[:, 1] <= 155.15105438232422 else to node 542.
# 											node=541 leaf node.
# 											node=542 test node: go to node 543 if X[:, 1] <= 155.67041015625 else to node 548.
# 												node=543 test node: go to node 544 if X[:, 0] <= 65.26837158203125 else to node 545.
# 													node=544 leaf node.
# 													node=545 test node: go to node 546 if X[:, 0] <= 65.3751449584961 else to node 547.
# 														node=546 leaf node.
# 														node=547 leaf node.
# 												node=548 leaf node.
# 									node=549 leaf node.
# 					node=550 test node: go to node 551 if X[:, 0] <= 63.86319351196289 else to node 572.
# 						node=551 test node: go to node 552 if X[:, 1] <= 157.86167907714844 else to node 553.
# 							node=552 leaf node.
# 							node=553 test node: go to node 554 if X[:, 0] <= 62.937984466552734 else to node 557.
# 								node=554 test node: go to node 555 if X[:, 0] <= 62.54303741455078 else to node 556.
# 									node=555 leaf node.
# 									node=556 leaf node.
# 								node=557 test node: go to node 558 if X[:, 1] <= 159.71278381347656 else to node 559.
# 									node=558 leaf node.
# 									node=559 test node: go to node 560 if X[:, 1] <= 159.9736099243164 else to node 561.
# 										node=560 leaf node.
# 										node=561 test node: go to node 562 if X[:, 0] <= 63.49262046813965 else to node 563.
# 											node=562 leaf node.
# 											node=563 test node: go to node 564 if X[:, 0] <= 63.728702545166016 else to node 571.
# 												node=564 test node: go to node 565 if X[:, 1] <= 160.34026336669922 else to node 566.
# 													node=565 leaf node.
# 													node=566 test node: go to node 567 if X[:, 0] <= 63.57064247131348 else to node 568.
# 														node=567 leaf node.
# 														node=568 test node: go to node 569 if X[:, 0] <= 63.6872501373291 else to node 570.
# 															node=569 leaf node.
# 															node=570 leaf node.
# 												node=571 leaf node.
# 						node=572 test node: go to node 573 if X[:, 0] <= 63.92419242858887 else to node 574.
# 							node=573 leaf node.
# 							node=574 test node: go to node 575 if X[:, 1] <= 162.74659729003906 else to node 666.
# 								node=575 test node: go to node 576 if X[:, 0] <= 64.3507308959961 else to node 599.
# 									node=576 test node: go to node 577 if X[:, 0] <= 64.32173538208008 else to node 598.
# 										node=577 test node: go to node 578 if X[:, 1] <= 156.71119689941406 else to node 579.
# 											node=578 leaf node.
# 											node=579 test node: go to node 580 if X[:, 1] <= 162.27303314208984 else to node 597.
# 												node=580 test node: go to node 581 if X[:, 0] <= 64.234130859375 else to node 596.
# 													node=581 test node: go to node 582 if X[:, 0] <= 64.15301895141602 else to node 595.
# 														node=582 test node: go to node 583 if X[:, 1] <= 161.72296142578125 else to node 594.
# 															node=583 test node: go to node 584 if X[:, 1] <= 161.32576751708984 else to node 593.
# 																node=584 test node: go to node 585 if X[:, 0] <= 64.10348129272461 else to node 592.
# 																	node=585 test node: go to node 586 if X[:, 0] <= 64.07707214355469 else to node 591.
# 																		node=586 test node: go to node 587 if X[:, 0] <= 63.96630668640137 else to node 590.
# 																			node=587 test node: go to node 588 if X[:, 0] <= 63.945682525634766 else to node 589.
# 																				node=588 leaf node.
# 																				node=589 leaf node.
# 																			node=590 leaf node.
# 																		node=591 leaf node.
# 																	node=592 leaf node.
# 																node=593 leaf node.
# 															node=594 leaf node.
# 														node=595 leaf node.
# 													node=596 leaf node.
# 												node=597 leaf node.
# 										node=598 leaf node.
# 									node=599 test node: go to node 600 if X[:, 1] <= 156.69707489013672 else to node 601.
# 										node=600 leaf node.
# 										node=601 test node: go to node 602 if X[:, 1] <= 156.90178680419922 else to node 605.
# 											node=602 test node: go to node 603 if X[:, 0] <= 65.34967803955078 else to node 604.
# 												node=603 leaf node.
# 												node=604 leaf node.
# 											node=605 test node: go to node 606 if X[:, 1] <= 157.11009979248047 else to node 607.
# 												node=606 leaf node.
# 												node=607 test node: go to node 608 if X[:, 1] <= 157.1231231689453 else to node 609.
# 													node=608 leaf node.
# 													node=609 test node: go to node 610 if X[:, 1] <= 157.34973907470703 else to node 611.
# 														node=610 leaf node.
# 														node=611 test node: go to node 612 if X[:, 1] <= 157.4728012084961 else to node 613.
# 															node=612 leaf node.
# 															node=613 test node: go to node 614 if X[:, 1] <= 157.77379608154297 else to node 615.
# 																node=614 leaf node.
# 																node=615 test node: go to node 616 if X[:, 1] <= 157.99541473388672 else to node 617.
# 																	node=616 leaf node.
# 																	node=617 test node: go to node 618 if X[:, 1] <= 158.1927032470703 else to node 619.
# 																		node=618 leaf node.
# 																		node=619 test node: go to node 620 if X[:, 1] <= 158.27715301513672 else to node 621.
# 																			node=620 leaf node.
# 																			node=621 test node: go to node 622 if X[:, 1] <= 158.4290771484375 else to node 623.
# 																				node=622 leaf node.
# 																				node=623 test node: go to node 624 if X[:, 1] <= 158.4498519897461 else to node 625.
# 																					node=624 leaf node.
# 																					node=625 test node: go to node 626 if X[:, 1] <= 162.60618591308594 else to node 665.
# 																						node=626 test node: go to node 627 if X[:, 1] <= 162.5575942993164 else to node 664.
# 																							node=627 test node: go to node 628 if X[:, 0] <= 65.53516006469727 else to node 663.
# 																								node=628 test node: go to node 629 if X[:, 0] <= 65.52659225463867 else to node 662.
# 																									node=629 test node: go to node 630 if X[:, 1] <= 159.01517486572266 else to node 631.
# 																										node=630 leaf node.
# 																										node=631 test node: go to node 632 if X[:, 1] <= 159.05987548828125 else to node 633.
# 																											node=632 leaf node.
# 																											node=633 test node: go to node 634 if X[:, 1] <= 159.5357208251953 else to node 635.
# 																												node=634 leaf node.
# 																												node=635 test node: go to node 636 if X[:, 1] <= 160.81839752197266 else to node 647.
# 																													node=636 test node: go to node 637 if X[:, 0] <= 65.34246444702148 else to node 646.
# 																														node=637 test node: go to node 638 if X[:, 1] <= 160.70692443847656 else to node 645.
# 																															node=638 test node: go to node 639 if X[:, 1] <= 159.90877532958984 else to node 640.
# 																																node=639 leaf node.
# 																																node=640 test node: go to node 641 if X[:, 0] <= 64.45229721069336 else to node 642.
# 																																	node=641 leaf node.
# 																																	node=642 test node: go to node 643 if X[:, 0] <= 65.18700408935547 else to node 644.
# 																																		node=643 leaf node.
# 																																		node=644 leaf node.
# 																															node=645 leaf node.
# 																														node=646 leaf node.
# 																													node=647 test node: go to node 648 if X[:, 1] <= 161.42586517333984 else to node 649.
# 																														node=648 leaf node.
# 																														node=649 test node: go to node 650 if X[:, 1] <= 161.54438018798828 else to node 651.
# 																															node=650 leaf node.
# 																															node=651 test node: go to node 652 if X[:, 0] <= 65.51156616210938 else to node 661.
# 																																node=652 test node: go to node 653 if X[:, 0] <= 64.71816635131836 else to node 660.
# 																																	node=653 test node: go to node 654 if X[:, 0] <= 64.67167663574219 else to node 659.
# 																																		node=654 test node: go to node 655 if X[:, 1] <= 162.41024780273438 else to node 656.
# 																																			node=655 leaf node.
# 																																			node=656 test node: go to node 657 if X[:, 0] <= 64.45446395874023 else to node 658.
# 																																				node=657 leaf node.
# 																																				node=658 leaf node.
# 																																		node=659 leaf node.
# 																																	node=660 leaf node.
# 																																node=661 leaf node.
# 																									node=662 leaf node.
# 																								node=663 leaf node.
# 																							node=664 leaf node.
# 																						node=665 leaf node.
# 								node=666 leaf node.
# 				node=667 test node: go to node 668 if X[:, 0] <= 67.70772171020508 else to node 845.
# 					node=668 test node: go to node 669 if X[:, 1] <= 156.95013427734375 else to node 718.
# 						node=669 test node: go to node 670 if X[:, 0] <= 65.80570220947266 else to node 671.
# 							node=670 leaf node.
# 							node=671 test node: go to node 672 if X[:, 0] <= 65.86010360717773 else to node 677.
# 								node=672 test node: go to node 673 if X[:, 1] <= 155.45368194580078 else to node 674.
# 									node=673 leaf node.
# 									node=674 test node: go to node 675 if X[:, 1] <= 156.3730926513672 else to node 676.
# 										node=675 leaf node.
# 										node=676 leaf node.
# 								node=677 test node: go to node 678 if X[:, 0] <= 66.1762809753418 else to node 679.
# 									node=678 leaf node.
# 									node=679 test node: go to node 680 if X[:, 1] <= 154.09420776367188 else to node 681.
# 										node=680 leaf node.
# 										node=681 test node: go to node 682 if X[:, 0] <= 66.79520416259766 else to node 699.
# 											node=682 test node: go to node 683 if X[:, 0] <= 66.72031784057617 else to node 698.
# 												node=683 test node: go to node 684 if X[:, 1] <= 155.82671356201172 else to node 695.
# 													node=684 test node: go to node 685 if X[:, 1] <= 154.39452362060547 else to node 686.
# 														node=685 leaf node.
# 														node=686 test node: go to node 687 if X[:, 0] <= 66.38526153564453 else to node 694.
# 															node=687 test node: go to node 688 if X[:, 0] <= 66.29043960571289 else to node 693.
# 																node=688 test node: go to node 689 if X[:, 1] <= 154.4010009765625 else to node 690.
# 																	node=689 leaf node.
# 																	node=690 test node: go to node 691 if X[:, 0] <= 66.24601364135742 else to node 692.
# 																		node=691 leaf node.
# 																		node=692 leaf node.
# 																node=693 leaf node.
# 															node=694 leaf node.
# 													node=695 test node: go to node 696 if X[:, 0] <= 66.18416595458984 else to node 697.
# 														node=696 leaf node.
# 														node=697 leaf node.
# 												node=698 leaf node.
# 											node=699 test node: go to node 700 if X[:, 0] <= 67.00322723388672 else to node 701.
# 												node=700 leaf node.
# 												node=701 test node: go to node 702 if X[:, 0] <= 67.13400650024414 else to node 709.
# 													node=702 test node: go to node 703 if X[:, 1] <= 155.5115203857422 else to node 704.
# 														node=703 leaf node.
# 														node=704 test node: go to node 705 if X[:, 1] <= 156.51414489746094 else to node 706.
# 															node=705 leaf node.
# 															node=706 test node: go to node 707 if X[:, 0] <= 67.06880569458008 else to node 708.
# 																node=707 leaf node.
# 																node=708 leaf node.
# 													node=709 test node: go to node 710 if X[:, 0] <= 67.28401565551758 else to node 711.
# 														node=710 leaf node.
# 														node=711 test node: go to node 712 if X[:, 0] <= 67.3194351196289 else to node 713.
# 															node=712 leaf node.
# 															node=713 test node: go to node 714 if X[:, 0] <= 67.56042098999023 else to node 715.
# 																node=714 leaf node.
# 																node=715 test node: go to node 716 if X[:, 0] <= 67.5745735168457 else to node 717.
# 																	node=716 leaf node.
# 																	node=717 leaf node.
# 						node=718 test node: go to node 719 if X[:, 0] <= 66.10196685791016 else to node 762.
# 							node=719 test node: go to node 720 if X[:, 1] <= 161.15029907226562 else to node 749.
# 								node=720 test node: go to node 721 if X[:, 0] <= 65.702392578125 else to node 722.
# 									node=721 leaf node.
# 									node=722 test node: go to node 723 if X[:, 0] <= 65.96707916259766 else to node 744.
# 										node=723 test node: go to node 724 if X[:, 0] <= 65.82564926147461 else to node 733.
# 											node=724 test node: go to node 725 if X[:, 0] <= 65.77496719360352 else to node 732.
# 												node=725 test node: go to node 726 if X[:, 0] <= 65.75934219360352 else to node 731.
# ...
# 											node=1290 leaf node.
# 											node=1291 test node: go to node 1292 if X[:, 1] <= 174.94884490966797 else to node 1293.
# 												node=1292 leaf node.
# 												node=1293 test node: go to node 1294 if X[:, 1] <= 175.05292510986328 else to node 1301.
# 													node=1294 test node: go to node 1295 if X[:, 1] <= 175.0387191772461 else to node 1300.
# 														node=1295 test node: go to node 1296 if X[:, 1] <= 175.01732635498047 else to node 1299.
# 															node=1296 test node: go to node 1297 if X[:, 0] <= 67.84580993652344 else to node 1298.
# 																node=1297 leaf node.
# 																node=1298 leaf node.
# 															node=1299 leaf node.
# 														node=1300 leaf node.
# 													node=1301 leaf node.
# 						node=1302 test node: go to node 1303 if X[:, 1] <= 177.99044036865234 else to node 1362.
# 							node=1303 test node: go to node 1304 if X[:, 1] <= 177.59102630615234 else to node 1361.
# 								node=1304 test node: go to node 1305 if X[:, 1] <= 177.4915771484375 else to node 1352.
# 									node=1305 test node: go to node 1306 if X[:, 0] <= 67.95369338989258 else to node 1307.
# 										node=1306 leaf node.
# 										node=1307 test node: go to node 1308 if X[:, 0] <= 67.962890625 else to node 1309.
# 											node=1308 leaf node.
# 											node=1309 test node: go to node 1310 if X[:, 1] <= 175.71752166748047 else to node 1311.
# 												node=1310 leaf node.
# 												node=1311 test node: go to node 1312 if X[:, 1] <= 176.16585540771484 else to node 1327.
# 													node=1312 test node: go to node 1313 if X[:, 1] <= 175.78652954101562 else to node 1314.
# 														node=1313 leaf node.
# 														node=1314 test node: go to node 1315 if X[:, 1] <= 175.86795043945312 else to node 1316.
# 															node=1315 leaf node.
# 															node=1316 test node: go to node 1317 if X[:, 0] <= 70.59323120117188 else to node 1326.
# 																node=1317 test node: go to node 1318 if X[:, 0] <= 69.20686340332031 else to node 1325.
# 																	node=1318 test node: go to node 1319 if X[:, 0] <= 68.37577819824219 else to node 1320.
# 																		node=1319 leaf node.
# 																		node=1320 test node: go to node 1321 if X[:, 0] <= 68.8232307434082 else to node 1322.
# 																			node=1321 leaf node.
# 																			node=1322 test node: go to node 1323 if X[:, 0] <= 69.11901473999023 else to node 1324.
# 																				node=1323 leaf node.
# 																				node=1324 leaf node.
# 																	node=1325 leaf node.
# 																node=1326 leaf node.
# 													node=1327 test node: go to node 1328 if X[:, 0] <= 69.10976791381836 else to node 1347.
# 														node=1328 test node: go to node 1329 if X[:, 0] <= 69.09058380126953 else to node 1346.
# 															node=1329 test node: go to node 1330 if X[:, 1] <= 177.23799896240234 else to node 1345.
# 																node=1330 test node: go to node 1331 if X[:, 1] <= 177.09798431396484 else to node 1344.
# 																	node=1331 test node: go to node 1332 if X[:, 1] <= 177.08431243896484 else to node 1343.
# 																		node=1332 test node: go to node 1333 if X[:, 1] <= 176.9205551147461 else to node 1342.
# 																			node=1333 test node: go to node 1334 if X[:, 1] <= 176.82421112060547 else to node 1339.
# 																				node=1334 test node: go to node 1335 if X[:, 0] <= 68.1113395690918 else to node 1338.
# 																					node=1335 test node: go to node 1336 if X[:, 1] <= 176.24703979492188 else to node 1337.
# 																						node=1336 leaf node.
# 																						node=1337 leaf node.
# 																					node=1338 leaf node.
# 																				node=1339 test node: go to node 1340 if X[:, 0] <= 69.04338836669922 else to node 1341.
# 																					node=1340 leaf node.
# 																					node=1341 leaf node.
# 																			node=1342 leaf node.
# 																		node=1343 leaf node.
# 																	node=1344 leaf node.
# 																node=1345 leaf node.
# 															node=1346 leaf node.
# 														node=1347 test node: go to node 1348 if X[:, 1] <= 176.57012939453125 else to node 1351.
# 															node=1348 test node: go to node 1349 if X[:, 1] <= 176.50789642333984 else to node 1350.
# 																node=1349 leaf node.
# 																node=1350 leaf node.
# 															node=1351 leaf node.
# 									node=1352 test node: go to node 1353 if X[:, 0] <= 67.88160705566406 else to node 1354.
# 										node=1353 leaf node.
# 										node=1354 test node: go to node 1355 if X[:, 1] <= 177.56185913085938 else to node 1356.
# 											node=1355 leaf node.
# 											node=1356 test node: go to node 1357 if X[:, 1] <= 177.5778350830078 else to node 1358.
# 												node=1357 leaf node.
# 												node=1358 test node: go to node 1359 if X[:, 1] <= 177.5880889892578 else to node 1360.
# 													node=1359 leaf node.
# 													node=1360 leaf node.
# 								node=1361 leaf node.
# 							node=1362 test node: go to node 1363 if X[:, 0] <= 69.09893035888672 else to node 1364.
# 								node=1363 leaf node.
# 								node=1364 leaf node.
# 					node=1365 leaf node.
# 		node=1366 test node: go to node 1367 if X[:, 1] <= 188.6978759765625 else to node 1500.
# 			node=1367 test node: go to node 1368 if X[:, 0] <= 68.60334777832031 else to node 1405.
# 				node=1368 test node: go to node 1369 if X[:, 1] <= 184.20509338378906 else to node 1404.
# 					node=1369 test node: go to node 1370 if X[:, 1] <= 184.15314483642578 else to node 1403.
# 						node=1370 test node: go to node 1371 if X[:, 1] <= 179.68758392333984 else to node 1372.
# 							node=1371 leaf node.
# 							node=1372 test node: go to node 1373 if X[:, 1] <= 179.73906707763672 else to node 1374.
# 								node=1373 leaf node.
# 								node=1374 test node: go to node 1375 if X[:, 1] <= 180.2739028930664 else to node 1376.
# 									node=1375 leaf node.
# 									node=1376 test node: go to node 1377 if X[:, 1] <= 180.29232025146484 else to node 1378.
# 										node=1377 leaf node.
# 										node=1378 test node: go to node 1379 if X[:, 1] <= 181.8088836669922 else to node 1394.
# 											node=1379 test node: go to node 1380 if X[:, 1] <= 181.78781127929688 else to node 1393.
# 												node=1380 test node: go to node 1381 if X[:, 1] <= 180.69110107421875 else to node 1382.
# 													node=1381 leaf node.
# 													node=1382 test node: go to node 1383 if X[:, 1] <= 180.7180404663086 else to node 1384.
# 														node=1383 leaf node.
# 														node=1384 test node: go to node 1385 if X[:, 1] <= 180.91869354248047 else to node 1386.
# 															node=1385 leaf node.
# 															node=1386 test node: go to node 1387 if X[:, 1] <= 180.9843292236328 else to node 1388.
# 																node=1387 leaf node.
# 																node=1388 test node: go to node 1389 if X[:, 0] <= 66.99788284301758 else to node 1392.
# 																	node=1389 test node: go to node 1390 if X[:, 0] <= 66.90282821655273 else to node 1391.
# 																		node=1390 leaf node.
# 																		node=1391 leaf node.
# 																	node=1392 leaf node.
# 												node=1393 leaf node.
# 											node=1394 test node: go to node 1395 if X[:, 0] <= 67.52437210083008 else to node 1396.
# 												node=1395 leaf node.
# 												node=1396 test node: go to node 1397 if X[:, 0] <= 67.57849502563477 else to node 1398.
# 													node=1397 leaf node.
# 													node=1398 test node: go to node 1399 if X[:, 1] <= 182.72119903564453 else to node 1402.
# 														node=1399 test node: go to node 1400 if X[:, 1] <= 182.69422912597656 else to node 1401.
# 															node=1400 leaf node.
# 															node=1401 leaf node.
# 														node=1402 leaf node.
# 						node=1403 leaf node.
# 					node=1404 leaf node.
# 				node=1405 test node: go to node 1406 if X[:, 1] <= 179.193359375 else to node 1431.
# 					node=1406 test node: go to node 1407 if X[:, 1] <= 178.2668228149414 else to node 1408.
# 						node=1407 leaf node.
# 						node=1408 test node: go to node 1409 if X[:, 1] <= 178.27957153320312 else to node 1410.
# 							node=1409 leaf node.
# 							node=1410 test node: go to node 1411 if X[:, 0] <= 68.62322998046875 else to node 1412.
# 								node=1411 leaf node.
# 								node=1412 test node: go to node 1413 if X[:, 0] <= 70.1937484741211 else to node 1430.
# 									node=1413 test node: go to node 1414 if X[:, 0] <= 69.85342407226562 else to node 1429.
# 										node=1414 test node: go to node 1415 if X[:, 0] <= 68.97982406616211 else to node 1424.
# 											node=1415 test node: go to node 1416 if X[:, 0] <= 68.69989013671875 else to node 1417.
# 												node=1416 leaf node.
# 												node=1417 test node: go to node 1418 if X[:, 1] <= 178.29161834716797 else to node 1419.
# 													node=1418 leaf node.
# 													node=1419 test node: go to node 1420 if X[:, 1] <= 178.72645568847656 else to node 1421.
# 														node=1420 leaf node.
# 														node=1421 test node: go to node 1422 if X[:, 0] <= 68.75186157226562 else to node 1423.
# 															node=1422 leaf node.
# 															node=1423 leaf node.
# 											node=1424 test node: go to node 1425 if X[:, 1] <= 178.9679183959961 else to node 1426.
# 												node=1425 leaf node.
# 												node=1426 test node: go to node 1427 if X[:, 0] <= 69.30051040649414 else to node 1428.
# 													node=1427 leaf node.
# 													node=1428 leaf node.
# 										node=1429 leaf node.
# 									node=1430 leaf node.
# 					node=1431 test node: go to node 1432 if X[:, 1] <= 188.68905639648438 else to node 1499.
# 						node=1432 test node: go to node 1433 if X[:, 0] <= 68.88846969604492 else to node 1434.
# 							node=1433 leaf node.
# 							node=1434 test node: go to node 1435 if X[:, 0] <= 68.90093994140625 else to node 1436.
# 								node=1435 leaf node.
# 								node=1436 test node: go to node 1437 if X[:, 0] <= 70.01430892944336 else to node 1460.
# 									node=1437 test node: go to node 1438 if X[:, 1] <= 186.82744598388672 else to node 1459.
# 										node=1438 test node: go to node 1439 if X[:, 1] <= 186.76795959472656 else to node 1458.
# 											node=1439 test node: go to node 1440 if X[:, 1] <= 181.61888122558594 else to node 1441.
# 												node=1440 leaf node.
# 												node=1441 test node: go to node 1442 if X[:, 1] <= 182.56893157958984 else to node 1449.
# 													node=1442 test node: go to node 1443 if X[:, 0] <= 69.35248184204102 else to node 1444.
# 														node=1443 leaf node.
# 														node=1444 test node: go to node 1445 if X[:, 0] <= 69.48319625854492 else to node 1446.
# 															node=1445 leaf node.
# 															node=1446 test node: go to node 1447 if X[:, 1] <= 182.4192123413086 else to node 1448.
# 																node=1447 leaf node.
# 																node=1448 leaf node.
# 													node=1449 test node: go to node 1450 if X[:, 0] <= 69.30929946899414 else to node 1457.
# 														node=1450 test node: go to node 1451 if X[:, 0] <= 69.29862976074219 else to node 1456.
# 															node=1451 test node: go to node 1452 if X[:, 1] <= 183.68373107910156 else to node 1455.
# 																node=1452 test node: go to node 1453 if X[:, 1] <= 183.61012268066406 else to node 1454.
# 																	node=1453 leaf node.
# 																	node=1454 leaf node.
# 																node=1455 leaf node.
# 															node=1456 leaf node.
# 														node=1457 leaf node.
# 											node=1458 leaf node.
# 										node=1459 leaf node.
# 									node=1460 test node: go to node 1461 if X[:, 0] <= 70.03000259399414 else to node 1462.
# 										node=1461 leaf node.
# 										node=1462 test node: go to node 1463 if X[:, 1] <= 182.20875549316406 else to node 1470.
# 											node=1463 test node: go to node 1464 if X[:, 1] <= 182.0646514892578 else to node 1469.
# 												node=1464 test node: go to node 1465 if X[:, 1] <= 180.14878845214844 else to node 1468.
# 													node=1465 test node: go to node 1466 if X[:, 1] <= 179.90390014648438 else to node 1467.
# 														node=1466 leaf node.
# 														node=1467 leaf node.
# 													node=1468 leaf node.
# 												node=1469 leaf node.
# 											node=1470 test node: go to node 1471 if X[:, 0] <= 72.2594108581543 else to node 1496.
# 												node=1471 test node: go to node 1472 if X[:, 1] <= 187.01012420654297 else to node 1495.
# 													node=1472 test node: go to node 1473 if X[:, 1] <= 186.9620361328125 else to node 1494.
# 														node=1473 test node: go to node 1474 if X[:, 1] <= 185.85665893554688 else to node 1493.
# 															node=1474 test node: go to node 1475 if X[:, 1] <= 185.84567260742188 else to node 1492.
# 																node=1475 test node: go to node 1476 if X[:, 1] <= 183.24199676513672 else to node 1477.
# 																	node=1476 leaf node.
# 																	node=1477 test node: go to node 1478 if X[:, 1] <= 183.4323272705078 else to node 1479.
# 																		node=1478 leaf node.
# 																		node=1479 test node: go to node 1480 if X[:, 1] <= 184.18113708496094 else to node 1481.
# 																			node=1480 leaf node.
# 																			node=1481 test node: go to node 1482 if X[:, 1] <= 184.21951293945312 else to node 1483.
# 																				node=1482 leaf node.
# 																				node=1483 test node: go to node 1484 if X[:, 1] <= 184.84707641601562 else to node 1485.
# 																					node=1484 leaf node.
# 																					node=1485 test node: go to node 1486 if X[:, 1] <= 184.9012908935547 else to node 1487.
# 																						node=1486 leaf node.
# 																						node=1487 test node: go to node 1488 if X[:, 0] <= 71.49795532226562 else to node 1489.
# 																							node=1488 leaf node.
# 																							node=1489 test node: go to node 1490 if X[:, 0] <= 71.60186767578125 else to node 1491.
# 																								node=1490 leaf node.
# 																								node=1491 leaf node.
# 																node=1492 leaf node.
# 															node=1493 leaf node.
# 														node=1494 leaf node.
# 													node=1495 leaf node.
# 												node=1496 test node: go to node 1497 if X[:, 0] <= 72.36768341064453 else to node 1498.
# 													node=1497 leaf node.
# 													node=1498 leaf node.
# 						node=1499 leaf node.
# 			node=1500 test node: go to node 1501 if X[:, 1] <= 196.12132263183594 else to node 1524.
# 				node=1501 test node: go to node 1502 if X[:, 0] <= 69.9366455078125 else to node 1503.
# 					node=1502 leaf node.
# 					node=1503 test node: go to node 1504 if X[:, 0] <= 69.95490646362305 else to node 1505.
# 						node=1504 leaf node.
# 						node=1505 test node: go to node 1506 if X[:, 1] <= 196.08314514160156 else to node 1523.
# 							node=1506 test node: go to node 1507 if X[:, 0] <= 73.2653694152832 else to node 1520.
# 								node=1507 test node: go to node 1508 if X[:, 0] <= 70.69607162475586 else to node 1509.
# 									node=1508 leaf node.
# 									node=1509 test node: go to node 1510 if X[:, 0] <= 70.71121215820312 else to node 1511.
# 										node=1510 leaf node.
# 										node=1511 test node: go to node 1512 if X[:, 1] <= 192.60318756103516 else to node 1519.
# 											node=1512 test node: go to node 1513 if X[:, 1] <= 192.14271545410156 else to node 1514.
# 												node=1513 leaf node.
# 												node=1514 test node: go to node 1515 if X[:, 1] <= 192.22687530517578 else to node 1516.
# 													node=1515 leaf node.
# 													node=1516 test node: go to node 1517 if X[:, 1] <= 192.4793930053711 else to node 1518.
# 														node=1517 leaf node.
# 														node=1518 leaf node.
# 											node=1519 leaf node.
# 								node=1520 test node: go to node 1521 if X[:, 0] <= 73.4469223022461 else to node 1522.
# 									node=1521 leaf node.
# 									node=1522 leaf node.
# 							node=1523 leaf node.
# 				node=1524 test node: go to node 1525 if X[:, 0] <= 70.35094833374023 else to node 1528.
# 					node=1525 test node: go to node 1526 if X[:, 0] <= 70.34881591796875 else to node 1527.
# 						node=1526 leaf node.
# 						node=1527 leaf node.
# 					node=1528 leaf node.
